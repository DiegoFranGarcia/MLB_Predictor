# %%
import requests
import pandas as pd
from datetime import date

def fetch_json(url):
    return requests.get(url).json()

def get_team_stats(team_id):
    url = f"https://statsapi.mlb.com/api/v1/teams/{team_id}/stats?stats=season&group=hitting,pitching"
    data = fetch_json(url)

    stats = {
        "win_pct": 0.0,
        "team_era": 0.0,
        "team_ops": 0.0
    }

    for group in data.get("stats", []):
        splits = group["splits"][0]["stat"]
        if group["group"]["displayName"] == "hitting":
            stats["team_ops"] = float(splits.get("ops", 0.0))
        elif group["group"]["displayName"] == "pitching":
            stats["team_era"] = float(splits.get("era", 0.0))

    # Fetch standings to calculate win percentage
    standings_url = f"https://statsapi.mlb.com/api/v1/teams/{team_id}/stats?stats=standings"
    standings_data = fetch_json(standings_url)

    try:
        team_record = standings_data["stats"][0]["splits"][0]["stat"]
        wins = int(team_record["wins"])
        losses = int(team_record["losses"])
        stats["win_pct"] = round(wins / (wins + losses), 3)
    except (KeyError, IndexError, ZeroDivisionError):
        stats["win_pct"] = 0.0  # fallback

    return stats


def get_pitcher_era(pitcher_id):
    url = f"https://statsapi.mlb.com/api/v1/people/{pitcher_id}/stats?stats=season&group=pitching"
    data = fetch_json(url)

    try:
        era = float(data["stats"][0]["splits"][0]["stat"]["era"])
    except (IndexError, KeyError):
        era = 0.0
    return era

def get_todays_game_features():
    today = date.today().isoformat()
    schedule = fetch_json(f"https://statsapi.mlb.com/api/v1/schedule?sportId=1&date={today}")
    
    if not schedule["dates"]:
        print(f"No games today: {today}")
        return pd.DataFrame()

    rows = []
    for game in schedule["dates"][0]["games"]:
        gamePk = game["gamePk"]
        home = game["teams"]["home"]["team"]
        away = game["teams"]["away"]["team"]

        game_data = fetch_json(f"https://statsapi.mlb.com/api/v1/game/{gamePk}/boxscore")

        try:
            home_pitcher_id = game_data["teams"]["home"]["players"][f'ID{game_data["teams"]["home"]["pitchers"][0]}']["person"]["id"]
            away_pitcher_id = game_data["teams"]["away"]["players"][f'ID{game_data["teams"]["away"]["pitchers"][0]}']["person"]["id"]
        except:
            home_pitcher_id = away_pitcher_id = None

        home_stats = get_team_stats(home["id"])
        away_stats = get_team_stats(away["id"])
        home_pitcher_era = get_pitcher_era(home_pitcher_id) if home_pitcher_id else 0.0
        away_pitcher_era = get_pitcher_era(away_pitcher_id) if away_pitcher_id else 0.0

        rows.append({
            "game_id": gamePk,
            "home_team": home["name"],
            "away_team": away["name"],
            "home_win_pct": home_stats["win_pct"],
            "away_win_pct": away_stats["win_pct"],
            "home_team_era": home_stats["team_era"],
            "away_team_era": away_stats["team_era"],
            "home_team_ops": home_stats["team_ops"],
            "away_team_ops": away_stats["team_ops"],
            "home_pitcher_era": home_pitcher_era,
            "away_pitcher_era": away_pitcher_era,
        })

    return pd.DataFrame(rows)

# Run and show results
df = get_todays_game_features()
print(df.to_string(index=False))
# Out:
#  game_id            home_team             away_team  home_win_pct  away_win_pct  home_team_era  away_team_era  home_team_ops  away_team_ops  home_pitcher_era  away_pitcher_era
#   777172    Chicago White Sox     Toronto Blue Jays           0.0           0.0           4.17           4.15          0.642          0.737              1.60              2.65
#   777175    Milwaukee Brewers   Los Angeles Dodgers           0.0           0.0           3.70           4.35          0.704          0.783              3.39              4.42
#   777163 San Francisco Giants Philadelphia Phillies           0.0           0.0           3.41           3.70          0.685          0.733              4.84              4.44
#   777182       Detroit Tigers        Tampa Bay Rays           0.0           0.0           3.42           3.79          0.751          0.730              0.00              0.00
#   777181    Baltimore Orioles         New York Mets           0.0           0.0           4.94           3.56          0.705          0.745              0.00              0.00
#   777184     New York Yankees      Seattle Mariners           0.0           0.0           3.83           3.84          0.792          0.728              0.00              0.00
#   777179       Boston Red Sox      Colorado Rockies           0.0           0.0           3.92           5.60          0.758          0.671              0.00              0.00
#   777183      Cincinnati Reds         Miami Marlins           0.0           0.0           4.03           4.62          0.708          0.707              0.00              0.00
#   777177   Kansas City Royals    Pittsburgh Pirates           0.0           0.0           3.46           3.67          0.670          0.642              0.00              0.00
#   777173      Minnesota Twins          Chicago Cubs           0.0           0.0           4.12           3.83          0.704          0.777              0.00              0.00
#   777178  St. Louis Cardinals  Washington Nationals           0.0           0.0           4.06           5.15          0.716          0.702              0.00              0.00
#   777174       Houston Astros   Cleveland Guardians           0.0           0.0           3.57           3.99          0.738          0.661              0.00              0.00
#   777171   Los Angeles Angels         Texas Rangers           0.0           0.0           4.57           3.23          0.701          0.667              0.00              0.00
#   777162     San Diego Padres  Arizona Diamondbacks           0.0           0.0           3.64           4.64          0.687          0.770              0.00              0.00
#   777176            Athletics        Atlanta Braves           0.0           0.0           5.28           3.85          0.733          0.697              0.00              0.00

# %%
import requests
import pandas as pd
from datetime import date

def fetch_json(url):
    return requests.get(url).json()

def parse_innings(ip_str):
    """Convert MLB innings-pitched string (e.g. "6.1") to float (6 + 1/3)."""
    if not ip_str:
        return 0.0
    parts = ip_str.split('.')
    innings = int(parts[0])
    if len(parts) > 1:
        try:
            innings += int(parts[1]) / 3
        except:
            pass
    return innings

def get_team_id_by_name(name):
    teams = fetch_json("https://statsapi.mlb.com/api/v1/teams?sportId=1")["teams"]
    for t in teams:
        if name.lower() in t["teamName"].lower() or name.lower() in t["name"].lower():
            return t["id"]
    raise ValueError(f"No MLB team found matching '{name}'")

def get_game_ops_era_whip(gamePk, side):
    box = fetch_json(f"https://statsapi.mlb.com/api/v1/game/{gamePk}/boxscore")["teams"][side]
    players = box["players"]

    # Batting for OPS
    agg = {"H":0, "AB":0, "BB":0, "HBP":0, "SF":0, "TB":0}
    for pid in box["batters"]:
        b = players[f"ID{pid}"]["stats"]["batting"]
        agg["H"]   += b.get("hits", 0)
        agg["AB"]  += b.get("atBats", 0)
        agg["BB"]  += b.get("baseOnBalls", 0)
        agg["HBP"] += b.get("hitByPitch", 0)
        agg["SF"]  += b.get("sacrificeFlies", 0)
        agg["TB"]  += b.get("totalBases", 0)

    denom = agg["AB"] + agg["BB"] + agg["HBP"] + agg["SF"]
    obp = (agg["H"] + agg["BB"] + agg["HBP"]) / denom if denom > 0 else 0.0
    slg = agg["TB"] / agg["AB"] if agg["AB"] > 0 else 0.0
    ops = round(obp + slg, 3)

    # Pitching for ERA & WHIP
    er_sum = ip_sum = hits_sum = bb_sum = 0
    for pid in box["pitchers"]:
        p = players[f"ID{pid}"]["stats"]["pitching"]
        er_sum   += p.get("earnedRuns", 0)
        ip_sum   += parse_innings(p.get("inningsPitched", "0.0"))
        hits_sum += p.get("hits", 0)
        bb_sum   += p.get("baseOnBalls", 0)

    era  = round(er_sum / ip_sum * 9, 3) if ip_sum else 0.0
    whip = round((hits_sum + bb_sum) / ip_sum, 3) if ip_sum else 0.0

    return ops, era, whip

def get_season_to_date_stats(team_id, season=None):
    """
    Pull every Regular-Season game from 'season' through today,
    compute OPS/ERA/WHIP/run differential for 'team_id',
    and add running home/away records.
    """
    if season is None:
        season = date.today().year

    today = date.today().isoformat()
    sched_url = (
        f"https://statsapi.mlb.com/api/v1/schedule"
        f"?sportId=1"
        f"&season={season}"
        f"&seasonType=2"              # Regular Season
        f"&teamId={team_id}"          # only this team’s games
        f"&startDate={season}-03-01"
        f"&endDate={today}"
    )
    sched = fetch_json(sched_url).get("dates", [])

    rows = []
    for day in sched:
        for g in day["games"]:
            if g["status"]["detailedState"] not in ["Final", "Completed Early"]:
                continue

            home = g["teams"]["home"]["team"]
            away = g["teams"]["away"]["team"]
            gamePk = g["gamePk"]

            # identify venue
            if team_id == home["id"]:
                venue, opp, ts, os_, side = "Home", away["name"], g["teams"]["home"]["score"], g["teams"]["away"]["score"], "home"
            else:
                venue, opp, ts, os_, side = "Away", home["name"], g["teams"]["away"]["score"], g["teams"]["home"]["score"], "away"

            result = "W" if ts > os_ else "L"
            ops, era, whip = get_game_ops_era_whip(gamePk, side)
            run_diff = ts - os_

            rows.append({
                "date":            day["date"],
                "venue":           venue,
                "opponent":        opp,
                "result":          result,
                "runs_scored":     ts,
                "runs_allowed":    os_,
                "run_differential": run_diff,
                "game_ops":        ops,
                "game_era":        era,
                "game_whip":       whip
            })

    # sort chronologically and add cumulative records
    rows = sorted(rows, key=lambda x: x["date"])
    home_wins = home_losses = away_wins = away_losses = 0
    for r in rows:
        if r["venue"] == "Home":
            if r["result"] == "W":
                home_wins += 1
            else:
                home_losses += 1
        else:  # Away
            if r["result"] == "W":
                away_wins += 1
            else:
                away_losses += 1

        r["home_record"] = f"{home_wins}-{home_losses}"
        r["away_record"] = f"{away_wins}-{away_losses}"

    return pd.DataFrame(rows)

if __name__ == "__main__":
    name = input("Enter (part of) MLB team name: ")
    tid  = get_team_id_by_name(name)
    df   = get_season_to_date_stats(tid)
    print(df.to_string(index=False))
# Out:
#       date venue             opponent result  runs_scored  runs_allowed  run_differential  game_ops  game_era  game_whip home_record away_record
# 2025-03-01  Home         Chicago Cubs      L            1            11               -10     0.608    11.000      2.222         0-1         0-0
# 2025-03-02  Away     San Diego Padres      W           10             4                 6     0.727     4.000      1.222         0-1         1-0
# 2025-03-03  Home        Texas Rangers      W            6             3                 3     0.833     3.000      1.000         1-1         1-0
# 2025-03-05  Home     Seattle Mariners      W            9             6                 3     0.969     6.000      1.222         2-1         1-0
# 2025-03-06  Away         Chicago Cubs      W            9             3                 6     0.921     3.000      0.889         2-1         2-0
# 2025-03-07  Home   Los Angeles Angels      W            8             2                 6     1.400     3.000      1.667         3-1         2-0
# 2025-03-08  Away San Francisco Giants      L            3             7                -4     0.719     7.875      1.625         3-1         2-1
# 2025-03-08  Away        Texas Rangers      L            3             5                -2     0.381     5.625      1.500         3-1         2-2
# 2025-03-09  Home    Milwaukee Brewers      W            5             2                 3     1.039     1.000      0.889         4-1         2-2
# 2025-03-10  Home  Cleveland Guardians      L            2             5                -3     0.706     5.000      1.556         4-2         2-2
# 2025-03-11  Away Arizona Diamondbacks      L            2             3                -1     0.771     3.375      1.750         4-2         2-3
# 2025-03-12  Away     Seattle Mariners      W            7             6                 1     0.996     5.000      1.222         4-2         3-3
# 2025-03-13  Home     San Diego Padres      W            6             5                 1     0.833     5.000      1.556         5-2         3-3
# 2025-03-14  Away   Los Angeles Angels      W            9             8                 1     0.919     5.000      1.778         5-2         4-3
# 2025-03-15  Away      Cincinnati Reds      W           13             7                 6     1.089     7.000      1.556         5-2         5-3
# 2025-03-15  Home  Cleveland Guardians      L            5             7                -2     0.904     7.000      1.889         5-3         5-3
# 2025-03-16  Away     Colorado Rockies      W           10             2                 8     0.795     2.000      1.444         5-3         6-3
# 2025-03-17  Home Arizona Diamondbacks      W           12             1                11     1.137     1.000      0.889         6-3         6-3
# 2025-03-19  Home San Francisco Giants      L            1             3                -2     0.519     3.000      0.889         6-4         6-3
# 2025-03-20  Away      Cincinnati Reds      W           11             8                 3     0.855     8.000      1.889         6-4         7-3
# 2025-03-21  Away            Athletics      L            1            10                -9     0.713    11.250      2.125         6-4         7-4
# 2025-03-21  Home     Seattle Mariners      W            8             7                 1     1.190     7.000      1.889         7-4         7-4
# 2025-03-22  Away        Texas Rangers      W            9             5                 4     1.143     5.000      0.778         7-4         8-4
# 2025-03-24  Away        Texas Rangers      L            3             6                -3     0.677     6.750      1.250         7-4         8-5
# 2025-03-25  Away        Texas Rangers      W            3             1                 2     0.686     1.000      1.111         7-4         9-5
# 2025-03-27  Home  Cleveland Guardians      L            4             7                -3     0.565     5.400      1.300         7-5         9-5
# 2025-03-29  Home  Cleveland Guardians      W            4             3                 1     0.767     3.000      1.000         8-5         9-5
# 2025-03-30  Home  Cleveland Guardians      L            2             6                -4     0.571     6.000      1.889         8-6         9-5
# 2025-03-31  Away    Milwaukee Brewers      W           11             1                10     0.974     1.000      1.000         8-6        10-5
# 2025-04-01  Away    Milwaukee Brewers      L            0             5                -5     0.476     4.500      1.250         8-6        10-6
# 2025-04-02  Away    Milwaukee Brewers      L            2             3                -1     0.310     0.871      1.452         8-6        10-7
# 2025-04-04  Home    Baltimore Orioles      W            8             2                 6     0.748     1.000      0.889         9-6        10-7
# 2025-04-05  Home    Baltimore Orioles      L            1             8                -7     0.515     8.000      1.889         9-7        10-7
# 2025-04-06  Home    Baltimore Orioles      W            4             1                 3     0.837     0.000      0.556        10-7        10-7
# 2025-04-07  Home      Minnesota Twins      W            4             2                 2     0.830     2.000      1.000        11-7        10-7
# 2025-04-08  Home      Minnesota Twins      W            2             1                 1     0.336     1.000      0.778        12-7        10-7
# 2025-04-09  Home      Minnesota Twins      L            0             4                -4     0.271     4.000      1.111        12-8        10-7
# 2025-04-10  Home      Minnesota Twins      W            3             2                 1     0.570     2.000      1.111        13-8        10-7
# 2025-04-11  Away  Cleveland Guardians      L            0             7                -7     0.467     4.500      1.875        13-8        10-8
# 2025-04-12  Away  Cleveland Guardians      L            3             6                -3     0.517     6.750      1.625        13-8        10-9
# 2025-04-13  Away  Cleveland Guardians      W            4             2                 2     0.739     1.000      0.556        13-8        11-9
# 2025-04-14  Away     New York Yankees      L            1             4                -3     0.354     4.500      1.375        13-8       11-10
# 2025-04-15  Away     New York Yankees      L            2             4                -2     0.518     4.500      1.500        13-8       11-11
# 2025-04-16  Away     New York Yankees      L            3             4                -1     0.476     4.500      1.500        13-8       11-12
# 2025-04-17  Away       Detroit Tigers      L            1             6                -5     0.558     6.750      2.125        13-8       11-13
# 2025-04-18  Away       Detroit Tigers      L            3             7                -4     0.750     7.875      1.875        13-8       11-14
# 2025-04-19  Away       Detroit Tigers      L            1             3                -2     0.516     3.375      1.000        13-8       11-15
# 2025-04-20  Away       Detroit Tigers      W            4             3                 1     0.506     2.700      1.200        13-8       12-15
# 2025-04-22  Home     Colorado Rockies      W            4             3                 1     0.724     2.455      1.000        14-8       12-15
# 2025-04-24  Home     Colorado Rockies      W            7             4                 3     0.952     4.000      0.778        15-8       12-15
# 2025-04-24  Home     Colorado Rockies      W            6             2                 4     0.759     2.000      1.444        16-8       12-15
# 2025-04-25  Home       Houston Astros      W            2             0                 2     0.741     0.000      0.444        17-8       12-15
# 2025-04-26  Home       Houston Astros      W            2             0                 2     0.448     0.000      0.889        18-8       12-15
# 2025-04-27  Home       Houston Astros      L            3             7                -4     0.790     7.000      1.333        18-9       12-15
# 2025-04-29  Away       Tampa Bay Rays      W            3             1                 2     0.596     1.000      1.111        18-9       13-15
# 2025-04-30  Away       Tampa Bay Rays      W            3             0                 3     0.741     0.000      1.000        18-9       14-15
# 2025-05-01  Away       Tampa Bay Rays      W            8             2                 6     0.983     2.000      0.889        18-9       15-15
# 2025-05-02  Away    Baltimore Orioles      L            0             3                -3     0.318     3.375      1.250        18-9       15-16
# 2025-05-03  Away    Baltimore Orioles      W            4             0                 4     0.827     0.000      0.889        18-9       16-16
# 2025-05-04  Away    Baltimore Orioles      W           11             6                 5     1.363     6.000      1.444        18-9       17-16
# 2025-05-05  Home    Chicago White Sox      W            3             0                 3     0.643     0.000      0.889        19-9       17-16
# 2025-05-06  Home    Chicago White Sox      W            4             3                 1     0.765     2.000      1.444        20-9       17-16
# 2025-05-07  Home    Chicago White Sox      W            2             1                 1     0.750     1.000      0.778        21-9       17-16
# 2025-05-08  Home    Chicago White Sox      W           10             0                10     1.039     0.000      0.778        22-9       17-16
# 2025-05-09  Home       Boston Red Sox      W            2             1                 1     0.561     0.000      0.500        23-9       17-16
# 2025-05-10  Home       Boston Red Sox      L            1            10                -9     0.548    10.000      2.111       23-10       17-16
# 2025-05-11  Home       Boston Red Sox      L            1             3                -2     0.285     3.000      1.000       23-11       17-16
# 2025-05-12  Away       Houston Astros      W            7             5                 2     0.789     4.000      1.556       23-11       18-16
# 2025-05-13  Away       Houston Astros      L            1             2                -1     0.483     2.250      1.000       23-11       18-17
# 2025-05-14  Away       Houston Astros      L            3             4                -1     0.736     4.500      1.250       23-11       18-18
# 2025-05-16  Home  St. Louis Cardinals      L            3            10                -7     0.750     9.000      1.556       23-12       18-18
# 2025-05-17  Home  St. Louis Cardinals      L            0             1                -1     0.354     1.000      0.222       23-13       18-18
# 2025-05-18  Home  St. Louis Cardinals      W            2             1                 1     0.749     1.000      1.444       24-13       18-18
# 2025-05-19  Away San Francisco Giants      W            3             1                 2     0.797     1.000      1.000       24-13       19-18
# 2025-05-20  Away San Francisco Giants      L            2             3                -1     0.540     2.250      1.375       24-13       19-19
# 2025-05-21  Away San Francisco Giants      W            8             4                 4     0.965     4.000      1.556       24-13       20-19
# 2025-05-23  Away      Minnesota Twins      L            1             3                -2     0.609     3.240      0.840       24-13       20-20
# 2025-05-24  Away      Minnesota Twins      L            4             5                -1     0.688     5.192      1.385       24-13       20-21
# 2025-05-25  Away      Minnesota Twins      W            2             1                 1     0.615     0.900      0.600       24-13       21-21
# 2025-05-26  Home      Cincinnati Reds      L            4             7                -3     0.628     7.000      1.889       24-14       21-21
# 2025-05-27  Home      Cincinnati Reds      L            2             7                -5     0.513     7.000      1.778       24-15       21-21
# 2025-05-28  Home      Cincinnati Reds      W            3             2                 1     0.732     2.000      1.222       25-15       21-21
# 2025-05-30  Home       Detroit Tigers      L            5             7                -2     0.891     7.000      1.556       25-16       21-21
# 2025-05-31  Home       Detroit Tigers      W            1             0                 1     0.333     0.000      0.444       26-16       21-21
# 2025-06-01  Home       Detroit Tigers      L            0             1                -1     0.580     1.000      0.889       26-17       21-21
# 2025-06-03  Away  St. Louis Cardinals      W           10             7                 3     0.879     7.000      1.889       26-17       22-21
# 2025-06-05  Away  St. Louis Cardinals      L            5             6                -1     0.758     3.857      1.179       26-17       22-22
# 2025-06-05  Away  St. Louis Cardinals      W            7             5                 2     0.918     5.000      1.222       26-17       23-22
# 2025-06-06  Away    Chicago White Sox      L            2             7                -5     0.681     5.625      1.750       26-17       23-23
# 2025-06-07  Away    Chicago White Sox      L            1             4                -3     0.639     4.500      1.250       26-17       23-24
# 2025-06-08  Away    Chicago White Sox      W            7             5                 2     1.151     5.000      1.000       26-17       24-24
# 2025-06-10  Home     New York Yankees      L            2            10                -8     0.623    10.000      2.111       26-18       24-24
# 2025-06-11  Home     New York Yankees      L            3             6                -3     0.650     6.000      1.444       26-19       24-24
# 2025-06-12  Home     New York Yankees      L            0             1                -1     0.438     0.000      1.000       26-20       24-24
# 2025-06-13  Home            Athletics      L            4             6                -2     0.649     6.000      1.556       26-21       24-24
# 2025-06-14  Home            Athletics      L            0             4                -4     0.343     4.000      1.000       26-22       24-24
# 2025-06-15  Home            Athletics      L            2             3                -1     0.568     3.000      1.333       26-23       24-24
# 2025-06-17  Away        Texas Rangers      W            6             1                 5     0.813     1.000      0.667       26-23       25-24
# 2025-06-18  Away        Texas Rangers      W            6             3                 3     0.691     3.000      1.444       26-23       26-24
# 2025-06-19  Away        Texas Rangers      W            4             1                 3     0.809     1.000      0.556       26-23       27-24
# 2025-06-20  Away     San Diego Padres      W            6             5                 1     0.915     5.000      1.889       26-23       28-24
# 2025-06-21  Away     San Diego Padres      L            1             5                -4     0.422     5.625      1.500       26-23       28-25
# 2025-06-22  Away     San Diego Padres      L            2             3                -1     0.629     3.240      0.960       26-23       28-26
# 2025-06-24  Home       Tampa Bay Rays      L            1             5                -4     0.350     3.000      1.333       26-24       28-26
# 2025-06-25  Home       Tampa Bay Rays      L            0             3                -3     0.315     3.000      1.333       26-25       28-26
# 2025-06-26  Home       Tampa Bay Rays      L            0             4                -4     0.394     4.000      1.111       26-26       28-26
# 2025-06-27  Home  Los Angeles Dodgers      L            4             5                -1     0.943     5.000      0.889       26-27       28-26
# 2025-06-28  Home  Los Angeles Dodgers      W            9             5                 4     1.047     5.000      1.778       27-27       28-26
# 2025-06-29  Home  Los Angeles Dodgers      L            1             5                -4     0.381     5.000      1.111       27-28       28-26
# 2025-06-30  Away     Seattle Mariners      L            2             6                -4     0.311     6.750      1.875       27-28       28-27
# 2025-07-01  Away     Seattle Mariners      W            6             3                 3     0.790     3.000      1.111       27-28       29-27
# 2025-07-02  Away     Seattle Mariners      L            2             3                -1     0.465     3.375      1.125       27-28       29-28
# 2025-07-03  Away     Seattle Mariners      W            3             2                 1     0.495     2.000      1.333       27-28       30-28
# 2025-07-04  Away Arizona Diamondbacks      W            9             3                 6     1.031     3.000      1.333       27-28       31-28
# 2025-07-05  Away Arizona Diamondbacks      L            1             7                -6     0.355     7.875      1.750       27-28       31-29
# 2025-07-06  Away Arizona Diamondbacks      W            4             0                 4     0.839     0.000      0.444       27-28       32-29
# 2025-07-07  Home   Pittsburgh Pirates      W            9             3                 6     1.212     3.000      0.778       28-28       32-29
# 2025-07-08  Home   Pittsburgh Pirates      W            4             3                 1     0.649     3.000      1.000       29-28       32-29
# 2025-07-09  Home   Pittsburgh Pirates      W            4             3                 1     1.114     3.000      1.111       30-28       32-29

# %%
#!/usr/bin/env python3
import asyncio
import aiohttp
import pandas as pd
import time
from datetime import date
from typing import Dict, Any
import nest_asyncio
import ssl
import certifi

nest_asyncio.apply()

# prepare SSL context
ssl_ctx = ssl.create_default_context(cafile=certifi.where())

def parse_innings(ip_str: str) -> float:
    if not ip_str:
        return 0.0
    parts = ip_str.split('.')
    innings = int(parts[0])
    if len(parts) > 1:
        try:
            innings += int(parts[1]) / 3
        except ValueError:
            pass
    return innings

async def fetch_json(session: aiohttp.ClientSession, url: str) -> Dict[str, Any]:
    async with session.get(url) as resp:
        resp.raise_for_status()
        return await resp.json()

async def compute_stats_for_side(box: Dict[str, Any], side: str) -> tuple[float, float, float]:
    b = box[side]
    players = b["players"]

    # OPS
    agg = {"H":0, "AB":0, "BB":0, "HBP":0, "SF":0, "TB":0}
    for pid in b["batters"]:
        st = players[f"ID{pid}"]["stats"]["batting"]
        agg["H"]   += st.get("hits", 0)
        agg["AB"]  += st.get("atBats", 0)
        agg["BB"]  += st.get("baseOnBalls", 0)
        agg["HBP"] += st.get("hitByPitch", 0)
        agg["SF"]  += st.get("sacrificeFlies", 0)
        agg["TB"]  += st.get("totalBases", 0)
    denom = agg["AB"] + agg["BB"] + agg["HBP"] + agg["SF"]
    obp   = (agg["H"] + agg["BB"] + agg["HBP"]) / denom if denom > 0 else 0.0
    slg   = agg["TB"] / agg["AB"] if agg["AB"] > 0 else 0.0
    ops   = round(obp + slg, 3)

    # ERA & WHIP
    er_sum = ip_sum = hits_sum = bb_sum = 0.0
    for pid in b["pitchers"]:
        pst = players[f"ID{pid}"]["stats"]["pitching"]
        er_sum   += pst.get("earnedRuns", 0)
        ip_sum   += parse_innings(pst.get("inningsPitched", "0.0"))
        hits_sum += pst.get("hits", 0)
        bb_sum   += pst.get("baseOnBalls", 0)
    era  = round((er_sum / ip_sum) * 9, 3) if ip_sum else 0.0
    whip = round((hits_sum + bb_sum) / ip_sum, 3) if ip_sum else 0.0

    return ops, era, whip

async def fetch_box_and_build_row(session: aiohttp.ClientSession, game: Dict[str, Any]) -> Dict[str, Any]:
    pk    = game["pk"]
    day   = game["date"]
    home  = game["home"]
    away  = game["away"]

    box = (await fetch_json(
        session,
        f"https://statsapi.mlb.com/api/v1/game/{pk}/boxscore"
    ))["teams"]

    h_ops, h_era, h_whip = await compute_stats_for_side(box, "home")
    a_ops, a_era, a_whip = await compute_stats_for_side(box, "away")
    hs, as_ = home["score"], away["score"]

    return {
        "date":           day,
        "home_team_id":   home["team"]["id"],
        "home_team":      home["team"]["name"],
        "away_team_id":   away["team"]["id"],
        "away_team":      away["team"]["name"],
        "home_score":     hs,
        "away_score":     as_,
        "home_ops":       h_ops,
        "home_era":       h_era,
        "home_whip":      h_whip,
        "away_ops":       a_ops,
        "away_era":       a_era,
        "away_whip":      a_whip,
        "result_home":    1 if hs > as_ else 0,
        "result_away":    1 if as_ > hs else 0,
    }

async def get_all_games_stats(season: int | None = None) -> pd.DataFrame:
    if season is None:
        season = date.today().year
    start_date = f"{season}-03-01"
    end_date   = date.today().isoformat()
    sched_url  = (
        f"https://statsapi.mlb.com/api/v1/schedule"
        f"?sportId=1&season={season}&seasonType=2"
        f"&startDate={start_date}&endDate={end_date}"
    )

    connector = aiohttp.TCPConnector(limit=100, ssl=ssl_ctx)
    async with aiohttp.ClientSession(connector=connector) as session:
        sched = (await fetch_json(session, sched_url)).get("dates", [])
        games = []
        for day in sched:
            for g in day["games"]:
                if g["status"]["detailedState"] not in ("Final", "Completed Early"):
                    continue
                games.append({
                    "date": day["date"],
                    "pk":   g["gamePk"],
                    "home": g["teams"]["home"],
                    "away": g["teams"]["away"]
                })

        # fetch & build rows in parallel
        tasks = [fetch_box_and_build_row(session, g) for g in games]
        rows  = await asyncio.gather(*tasks)

    df = pd.DataFrame(rows).sort_values("date").reset_index(drop=True)

    # 1) cumulative home/away win percentages
    home_rec = {}   # team_id -> (wins, losses)
    away_rec = {}
    home_win_pct = []
    away_win_pct = []

    for _, r in df.iterrows():
        hid = r["home_team_id"]
        aid = r["away_team_id"]

        hw, hl = home_rec.get(hid, (0, 0))
        aw, al = away_rec.get(aid, (0, 0))

        total_h = hw + hl
        total_a = aw + al
        home_win_pct.append(hw / total_h if total_h > 0 else 0.0)
        away_win_pct.append(aw / total_a if total_a > 0 else 0.0)

        if r["result_home"] == 1:
            hw += 1
        else:
            hl += 1
        if r["result_away"] == 1:
            aw += 1
        else:
            al += 1

        home_rec[hid] = (hw, hl)
        away_rec[aid] = (aw, al)

    df["home_win_pct"] = home_win_pct
    df["away_win_pct"] = away_win_pct

    # 2) cumulative averages of OPS/ERA/WHIP by location
    home_stats = {}   # team_id → {'ops', 'era', 'whip', 'count'}
    away_stats = {}
    home_avg_ops, home_avg_era, home_avg_whip = [], [], []
    away_avg_ops, away_avg_era, away_avg_whip = [], [], []

    for _, r in df.iterrows():
        hid = r["home_team_id"]
        h = home_stats.get(hid, {"ops":0.0,"era":0.0,"whip":0.0,"count":0})
        cnt = h["count"]
        home_avg_ops .append(h["ops"]/cnt if cnt else 0.0)
        home_avg_era .append(h["era"]/cnt if cnt else 0.0)
        home_avg_whip.append(h["whip"]/cnt if cnt else 0.0)
        h["ops"]   += r["home_ops"]
        h["era"]   += r["home_era"]
        h["whip"]  += r["home_whip"]
        h["count"] += 1
        home_stats[hid] = h

        aid = r["away_team_id"]
        a = away_stats.get(aid, {"ops":0.0,"era":0.0,"whip":0.0,"count":0})
        cnt2 = a["count"]
        away_avg_ops .append(a["ops"]/cnt2 if cnt2 else 0.0)
        away_avg_era .append(a["era"]/cnt2 if cnt2 else 0.0)
        away_avg_whip.append(a["whip"]/cnt2 if cnt2 else 0.0)
        a["ops"]   += r["away_ops"]
        a["era"]   += r["away_era"]
        a["whip"]  += r["away_whip"]
        a["count"] += 1
        away_stats[aid] = a

    df["home_avg_ops"]  = home_avg_ops
    df["home_avg_era"]  = home_avg_era
    df["home_avg_whip"] = home_avg_whip
    df["away_avg_ops"]  = away_avg_ops
    df["away_avg_era"]  = away_avg_era
    df["away_avg_whip"] = away_avg_whip

    # drop raw stats and ID columns
    df = df.drop(columns=[
        "home_team_id", "away_team_id",
        "home_ops", "home_era", "home_whip",
        "away_ops", "away_era", "away_whip"
    ])

    return df

def main():
    start = time.perf_counter()
    df = asyncio.run(get_all_games_stats())
    elapsed = time.perf_counter() - start
    print(f"Fetched and processed {len(df)} games in {elapsed:.1f}s")
    print(df.to_string(index=True))
    df.to_csv("mlb_games_stats.csv", index=False)

if __name__ == "__main__":
    main()
# Out:
# Fetched and processed 1869 games in 5.3s
#             date                  home_team                  away_team  home_score  away_score  result_home  result_away  home_win_pct  away_win_pct  home_avg_ops  home_avg_era  home_avg_whip  away_avg_ops  away_avg_era  away_avg_whip
# 0     2025-03-01          Baltimore Orioles         Pittsburgh Pirates           2           5            0            1      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 1     2025-03-01         Kansas City Royals               Chicago Cubs           1          11            0            1      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 2     2025-03-01       Washington Nationals              Miami Marlins           7           0            1            0      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 3     2025-03-01          Milwaukee Brewers              Texas Rangers           9           4            1            0      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 4     2025-03-01           Seattle Mariners          Chicago White Sox           9          18            0            1      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 5     2025-03-01       Arizona Diamondbacks           Colorado Rockies           8           4            1            0      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 6     2025-03-01        Los Angeles Dodgers       San Francisco Giants           6           5            1            0      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 7     2025-03-01            Cincinnati Reds           San Diego Padres           7           3            1            0      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 8     2025-03-01         Los Angeles Angels                  Athletics           5           0            1            0      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 9     2025-03-01           New York Yankees             Houston Astros           9           3            1            0      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 10    2025-03-01             Atlanta Braves          Toronto Blue Jays           1           1            0            0      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 11    2025-03-01             Detroit Tigers      Philadelphia Phillies           1           0            1            0      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 12    2025-03-01             Boston Red Sox            Minnesota Twins           8           4            1            0      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 13    2025-03-01             Tampa Bay Rays              New York Mets           1          10            0            1      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 14    2025-03-01        St. Louis Cardinals       Washington Nationals           3           2            1            0      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 15    2025-03-01               Chicago Cubs        Cleveland Guardians           7           4            1            0      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 16    2025-03-02                  Athletics        Los Angeles Dodgers           4           8            0            1      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 17    2025-03-02           Colorado Rockies           Seattle Mariners           6           1            1            0      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 18    2025-03-02        Cleveland Guardians          Milwaukee Brewers          12          12            0            0      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 19    2025-03-02        Los Angeles Dodgers          Chicago White Sox           6           3            1            0      1.000000      1.000000      0.943000      5.000000       1.111000      1.304000      8.000000       1.889000
# 20    2025-03-02              Texas Rangers       Arizona Diamondbacks           6           3            1            0      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 21    2025-03-02       San Francisco Giants         Los Angeles Angels           9           5            1            0      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 22    2025-03-02               Chicago Cubs            Cincinnati Reds           3           7            0            1      1.000000      0.000000      0.905000      4.000000       1.000000      0.000000      0.000000       0.000000
# 23    2025-03-02           San Diego Padres         Kansas City Royals           4          10            0            1      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 24    2025-03-02          Toronto Blue Jays      Philadelphia Phillies           5           4            1            0      0.000000      0.000000      0.000000      0.000000       0.000000      0.165000      1.125000       1.000000
# 25    2025-03-02             Atlanta Braves           New York Yankees          11           1            1            0      0.000000      0.000000      0.552000      1.000000       0.889000      0.000000      0.000000       0.000000
# 26    2025-03-02      Philadelphia Phillies          Baltimore Orioles           5           4            1            0      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 27    2025-03-02            Minnesota Twins             Tampa Bay Rays           5           5            0            0      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 28    2025-03-02         Pittsburgh Pirates             Detroit Tigers           4          10            0            1      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 29    2025-03-02             Boston Red Sox              New York Mets           6           4            1            0      1.000000      1.000000      1.055000      2.000000       0.889000      0.759000      1.000000       0.556000
# 30    2025-03-02             Houston Astros       Washington Nationals           3           4            0            1      0.000000      0.000000      0.000000      0.000000       0.000000      0.538000      3.115000       1.385000
# 31    2025-03-02              Miami Marlins        St. Louis Cardinals           5           3            1            0      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 32    2025-03-03            Cincinnati Reds          Milwaukee Brewers           5           4            1            0      1.000000      0.000000      0.861000      2.000000       1.778000      1.024000     11.000000       2.222000
# 33    2025-03-03              New York Mets              Miami Marlins           1           1            0            0      0.000000      0.000000      0.000000      0.000000       0.000000      0.321000      7.875000       1.375000
# 34    2025-03-03           Seattle Mariners        Cleveland Guardians           7           2            1            0      0.000000      0.000000      0.985000     18.000000       2.667000      0.765000      7.875000       2.125000
# 35    2025-03-03         Los Angeles Angels           Colorado Rockies           4           8            0            1      1.000000      0.000000      0.549000      0.000000       0.444000      0.737000      7.875000       1.500000
# 36    2025-03-03       Arizona Diamondbacks               Chicago Cubs          10           2            1            0      1.000000      1.000000      0.980000      4.000000       1.333000      1.141000      1.000000       1.111000
# 37    2025-03-03           New York Yankees         Pittsburgh Pirates          12           3            1            0      1.000000      1.000000      0.870000      3.000000       1.000000      0.938000      2.000000       1.000000
# 38    2025-03-03         Kansas City Royals              Texas Rangers           6           3            1            0      0.000000      0.000000      0.608000     11.000000       2.222000      0.767000     10.125000       1.875000
# 39    2025-03-03              Miami Marlins             Houston Astros           3           5            0            1      1.000000      0.000000      0.932000      3.000000       0.778000      0.395000     10.125000       1.250000
# 40    2025-03-03             Tampa Bay Rays             Atlanta Braves           5           4            1            0      0.000000      0.000000      0.356000     10.000000       1.778000      0.000000      0.000000       0.000000
# 41    2025-03-03             Detroit Tigers          Toronto Blue Jays           3          13            0            1      1.000000      0.000000      0.526000      0.000000       0.444000      0.409000      1.000000       1.000000
# 42    2025-03-03          Baltimore Orioles             Boston Red Sox           6           6            0            0      0.000000      0.000000      0.500000      5.000000       1.444000      0.000000      0.000000       0.000000
# 43    2025-03-03          Chicago White Sox                  Athletics           4           5            0            1      0.000000      0.000000      0.000000      0.000000       0.000000      0.290000      4.500000       1.250000
# 44    2025-03-04        Los Angeles Dodgers            Cincinnati Reds           4           2            1            0      1.000000      1.000000      0.896000      4.000000       1.166500      1.024000      3.000000       1.333000
# 45    2025-03-04           San Diego Padres       San Francisco Giants           1           1            0            0      0.000000      0.000000      0.639000      5.000000       1.667000      0.724000      6.750000       1.500000
# 46    2025-03-04           Colorado Rockies            Cincinnati Reds           9           5            1            0      1.000000      0.500000      0.626000      1.000000       0.889000      0.822500      2.625000       1.354000
# 47    2025-03-04              Texas Rangers                  Athletics           3           6            0            1      1.000000      0.500000      0.973000      3.000000       1.111000      0.540500      4.250000       1.069500
# 48    2025-03-04               Chicago Cubs           San Diego Padres          16           1            1            0      0.500000      0.000000      0.772500      5.500000       1.333500      0.715000      7.875000       1.500000
# 49    2025-03-04        Cleveland Guardians         Los Angeles Angels           8           1            1            0      0.000000      0.000000      1.021000     11.000000       2.000000      0.693000     10.125000       1.750000
# 50    2025-03-04      Philadelphia Phillies           New York Yankees           3          12            0            1      1.000000      0.000000      0.875000      1.000000       0.889000      0.557000      5.625000       1.875000
# 51    2025-03-04             Tampa Bay Rays             Detroit Tigers           4           1            1            0      0.500000      1.000000      0.576000      7.000000       1.444500      1.034000      4.000000       1.111000
# 52    2025-03-04        St. Louis Cardinals              New York Mets           6           1            1            0      1.000000      0.500000      0.609000      2.000000       1.000000      0.666000      3.312500       1.028000
# 53    2025-03-04       Washington Nationals        St. Louis Cardinals           4           6            0            1      1.000000      0.000000      0.698000      0.000000       0.667000      0.528000      5.625000       2.000000
# 54    2025-03-04         Pittsburgh Pirates             Boston Red Sox           4          12            0            1      0.000000      0.000000      0.760000     10.000000       1.778000      0.869000      5.000000       1.333000
# 55    2025-03-04             Atlanta Braves            Minnesota Twins           0           0            0            0      0.500000      0.000000      0.836000      1.000000       1.055500      0.416000      9.000000       2.250000
# 56    2025-03-05         Los Angeles Angels        Los Angeles Dodgers           3           5            0            1      0.500000      1.000000      0.642000      4.000000       1.166500      0.921000      1.000000       0.778000
# 57    2025-03-05         Kansas City Royals           Seattle Mariners           9           6            1            0      0.500000      0.000000      0.720500      7.000000       1.611000      0.437000      6.750000       1.250000
# 58    2025-03-05          Milwaukee Brewers          Chicago White Sox           2           8            0            1      1.000000      0.500000      1.260000      3.000000       1.222000      0.953500      6.812500       1.694500
# 59    2025-03-05       Arizona Diamondbacks       San Francisco Giants           5          11            0            1      1.000000      0.000000      1.061500      3.000000       1.388500      0.545000      3.875000       1.305500
# 60    2025-03-05           San Diego Padres           Colorado Rockies           3           4            0            1      0.000000      0.500000      0.596500      3.000000       1.167000      0.785500      5.937500       1.361000
# 61    2025-03-05          Chicago White Sox          Milwaukee Brewers           2           3            0            1      0.000000      0.000000      0.686000      5.000000       1.778000      0.875500      6.625000       2.111000
# 62    2025-03-05            Minnesota Twins          Baltimore Orioles           2           5            0            1      0.000000      0.000000      0.975000      5.000000       1.333000      0.410000      5.192000       1.269000
# 63    2025-03-05              Miami Marlins       Washington Nationals           7           8            0            1      0.500000      0.500000      0.801500      2.500000       0.944500      0.620500      3.057500       1.581500
# 64    2025-03-05             Detroit Tigers      Philadelphia Phillies          17           7            1            0      0.500000      0.000000      0.610500      6.000000       1.222000      0.419500      3.375000       1.562500
# 65    2025-03-05            Cincinnati Reds              Texas Rangers           3           5            0            1      1.000000      0.000000      0.809500      3.000000       1.444500      0.659000      6.750000       1.687500
# 66    2025-03-05         Pittsburgh Pirates          Toronto Blue Jays           7           6            1            0      0.000000      0.500000      0.754500     10.500000       1.889000      0.716000      2.000000       1.333500
# 67    2025-03-05             Boston Red Sox             Tampa Bay Rays           4           2            1            0      1.000000      0.000000      0.868500      3.000000       0.889000      0.842000      5.000000       1.778000
# 68    2025-03-05             Houston Astros        St. Louis Cardinals           6           5            1            0      0.000000      0.500000      0.646000      2.000000       1.556000      0.599500      4.812500       1.666500
# 69    2025-03-06       Arizona Diamondbacks           Seattle Mariners          11           4            1            0      0.666667      0.000000      1.019333      5.666667       1.851667      0.618000      8.437500       1.500000
# 70    2025-03-06           Seattle Mariners         Los Angeles Angels           5           5            0            0      0.500000      0.000000      0.991500     10.000000       1.889000      0.700000      9.562500       1.750000
# 71    2025-03-06                  Athletics          Milwaukee Brewers           0          10            0            1      0.000000      0.333333      0.487000      8.000000       1.556000      0.805000      5.083333       1.740667
# 72    2025-03-06               Chicago Cubs         Kansas City Royals           3           9            0            1      0.666667      1.000000      0.872333      4.000000       1.185333      0.727000      4.000000       1.222000
# 73    2025-03-06        Cleveland Guardians       Arizona Diamondbacks           4           0            1            0      0.500000      0.000000      0.972500      6.000000       1.611000      0.677000      6.750000       1.250000
# 74    2025-03-06              New York Mets             Houston Astros           1           5            0            1      0.000000      0.500000      0.259000      1.000000       1.000000      0.533500      6.562500       1.403000
# 75    2025-03-06             Atlanta Braves              Miami Marlins           1           1            0            0      0.333333      0.000000      0.710000      0.666667       0.963000      0.400000      3.937500       1.021000
# 76    2025-03-06       San Francisco Giants          Chicago White Sox           7           3            1            0      1.000000      0.666667      0.775000      5.000000       1.444000      0.956333      5.208333       1.500000
# 77    2025-03-06              Texas Rangers           San Diego Padres           8           2            1            0      0.500000      0.000000      0.819000      4.500000       1.333500      0.586500     10.687500       2.125000
# 78    2025-03-06        Los Angeles Dodgers              Texas Rangers           8           4            1            0      1.000000      0.333333      0.854333      3.333333       1.074000      0.654667      5.500000       1.458333
# 79    2025-03-06          Toronto Blue Jays             Boston Red Sox           7           4            1            0      1.000000      0.500000      1.047000      4.000000       1.000000      0.905000      4.500000       1.277500
# 80    2025-03-06           New York Yankees            Minnesota Twins           4           8            0            1      1.000000      0.000000      0.912000      3.000000       0.944500      0.403000      4.500000       1.680500
# 81    2025-03-06      Philadelphia Phillies             Tampa Bay Rays           4           5            0            1      0.500000      0.000000      0.734000      4.000000       1.278000      0.739000      4.187500       1.701500
# 82    2025-03-06        St. Louis Cardinals       Washington Nationals           1          12            0            1      1.000000      0.666667      0.778000      1.000000       0.889000      0.772000      4.371667       1.573000
# 83    2025-03-06          Baltimore Orioles         Pittsburgh Pirates           5           9            0            1      0.000000      0.500000      0.604000      5.500000       1.500000      0.710500      7.187500       1.625000
# 84    2025-03-07             Detroit Tigers          Baltimore Orioles          11           7            1            0      0.666667      0.500000      0.871000      6.333333       1.259000      0.580500      3.596000       1.301000
# 85    2025-03-07           New York Yankees          Toronto Blue Jays           8           7            1            0      0.666667      0.333333      0.827333      4.666667       1.259333      0.812667      3.958333       1.472333
# 86    2025-03-07        St. Louis Cardinals             Houston Astros           6           4            1            0      0.666667      0.666667      0.655000      2.333333       1.296333      0.594667      4.708333       1.416667
# 87    2025-03-07           Seattle Mariners        Los Angeles Dodgers           4           6            0            1      0.333333      1.000000      0.893333      7.666667       1.778000      0.800500      1.500000       0.833500
# 88    2025-03-07                  Athletics        Cleveland Guardians           5          12            0            1      0.000000      0.000000      0.356500      7.500000       1.778000      0.774000      7.875000       2.000000
# 89    2025-03-07       Washington Nationals              New York Mets           5           4            1            0      0.500000      0.333333      0.616500      3.000000       0.944500      0.564667      4.458333       1.185333
# 90    2025-03-07             Boston Red Sox              Miami Marlins          20           5            1            0      1.000000      0.000000      0.843333      2.666667       1.037000      0.416667      2.958333       0.940000
# 91    2025-03-07            Minnesota Twins             Atlanta Braves           7           1            1            0      0.000000      0.000000      0.819500      5.000000       1.444500      0.590000      4.500000       2.000000
# 92    2025-03-07         Pittsburgh Pirates      Philadelphia Phillies           3           2            1            0      0.333333      0.000000      0.803000      9.000000       1.778000      0.558000      8.625000       2.000000
# 93    2025-03-07             Tampa Bay Rays            Minnesota Twins           9           9            0            0      0.666667      0.333333      0.654667      5.000000       1.296333      0.606000      4.000000       1.639000
# 94    2025-03-07         Kansas City Royals         Los Angeles Angels           8           2            1            0      0.666667      0.000000      0.803333      6.666667       1.481333      0.704333      8.041667       1.574000
# 95    2025-03-08              Miami Marlins              New York Mets           3           7            0            1      0.333333      0.250000      0.777000      4.333333       1.185333      0.559000      4.468750       1.357750
# 96    2025-03-08             Houston Astros           New York Yankees           5           2            1            0      0.500000      0.500000      0.783500      3.500000       1.667000      0.762000      4.312500       1.548500
# 97    2025-03-08                  Athletics       Arizona Diamondbacks           4           2            1            0      0.000000      0.000000      0.486333      9.000000       1.852000      0.553000      5.625000       1.062500
# 98    2025-03-08          Milwaukee Brewers         Los Angeles Angels           2           6            0            1      0.500000      0.000000      0.934500      5.000000       1.500000      0.710750      9.631250       1.680500
# 99    2025-03-08           San Diego Padres        Cleveland Guardians           7           2            1            0      0.000000      0.333333      0.556333      2.666667       1.185333      0.959333      6.916667       2.037000
# 100   2025-03-08           Colorado Rockies                  Athletics           1           8            0            1      1.000000      0.666667      0.870000      3.000000       1.222500      0.680000      3.166667       1.046333
# 101   2025-03-08          Chicago White Sox        Los Angeles Dodgers           5           2            1            0      0.000000      1.000000      0.629000      3.500000       1.444500      0.802667      2.333333       0.889000
# 102   2025-03-08       San Francisco Giants         Kansas City Royals           7           3            1            0      1.000000      1.000000      0.929500      4.000000       1.166500      0.824000      3.500000       1.055500
# 103   2025-03-08              Texas Rangers         Kansas City Royals           5           3            1            0      0.666667      0.666667      0.910333      3.666667       1.074333      0.789000      4.958333       1.245333
# 104   2025-03-08            Cincinnati Reds       Arizona Diamondbacks           9           8            1            0      0.666667      0.000000      0.745667      3.666667       1.444333      0.541667      5.250000       1.000000
# 105   2025-03-08          Toronto Blue Jays             Detroit Tigers           5           0            1            0      1.000000      0.500000      1.002000      4.000000       1.278000      0.758500      4.250000       1.180500
# 106   2025-03-08             Atlanta Braves         Pittsburgh Pirates           6           5            1            0      0.250000      0.666667      0.630250      0.750000       0.944500      0.783667      6.458333       1.564667
# 107   2025-03-08      Philadelphia Phillies          Toronto Blue Jays           5           4            1            0      0.333333      0.250000      0.723333      3.000000       1.370667      0.813500      5.128750       1.644250
# 108   2025-03-08            Minnesota Twins             Boston Red Sox           9           8            1            0      0.333333      0.333333      0.828667      3.666667       1.407333      0.865667      5.250000       1.476667
# 109   2025-03-08          Baltimore Orioles             Tampa Bay Rays           3           6            0            1      0.000000      0.333333      0.619333      6.333333       1.666667      0.726667      4.125000       1.578667
# 110   2025-03-08       Washington Nationals        St. Louis Cardinals           3           5            0            1      0.666667      0.333333      0.738000      2.666667       1.000000      0.719667      4.939000       1.534000
# 111   2025-03-08               Chicago Cubs           Seattle Mariners           9           8            1            0      0.500000      0.000000      0.792500      5.250000       1.305750      0.628000      8.625000       1.875000
# 112   2025-03-09               Chicago Cubs       San Francisco Giants           6           8            0            1      0.600000      0.333333      0.847200      5.800000       1.289000      0.725000      4.250000       1.351667
# 113   2025-03-09       Arizona Diamondbacks              Texas Rangers          14           1            1            0      0.750000      0.250000      1.005750      5.250000       1.805500      0.705750      6.093750       1.625000
# 114   2025-03-09           Seattle Mariners           Colorado Rockies           8           1            1            0      0.250000      0.666667      0.830250      7.000000       1.750250      0.693333      4.625000       1.240667
# 115   2025-03-09         Los Angeles Angels            Cincinnati Reds           4           1            1            0      0.333333      0.333333      0.618667      4.333333       1.185000      0.862333      5.125000       1.694333
# 116   2025-03-09         Kansas City Royals          Milwaukee Brewers           5           2            1            0      0.750000      0.500000      0.952500      5.750000       1.527750      0.804750      3.812500       1.388750
# 117   2025-03-09        Cleveland Guardians          Chicago White Sox           1           0            1            0      0.666667      0.500000      0.883667      4.000000       1.370333      0.859500      5.875000       1.468750
# 118   2025-03-09       San Francisco Giants           San Diego Padres           7           4            1            0      1.000000      0.000000      0.962333      3.666667       1.185000      0.590333     10.125000       2.125000
# 119   2025-03-09        Los Angeles Dodgers                  Athletics           5           7            0            1      1.000000      0.750000      0.920500      3.500000       1.194500      0.705250      2.625000       1.090250
# 120   2025-03-09             Detroit Tigers         Pittsburgh Pirates           5           3            1            0      0.750000      0.500000      0.958000      6.500000       1.305250      0.809250      6.193750       1.563500
# 121   2025-03-09              New York Mets       Washington Nationals           7           6            1            0      0.000000      0.750000      0.409500      3.000000       1.333500      0.815500      3.528750       1.402000
# 122   2025-03-09        St. Louis Cardinals           New York Yankees           6           5            1            0      0.750000      0.333333      0.743500      2.750000       1.277750      0.727333      4.605667       1.570667
# 123   2025-03-09             Houston Astros              Miami Marlins           6          10            0            1      0.666667      0.000000      0.822333      2.666667       1.555667      0.501750      7.843750       1.517500
# 124   2025-03-09             Boston Red Sox             Atlanta Braves           7           3            1            0      1.000000      0.000000      1.036250      3.000000       1.194500      0.665500      5.062500       1.937500
# 125   2025-03-09      Philadelphia Phillies          Baltimore Orioles          12           2            1            0      0.500000      0.333333      0.753500      3.250000       1.333500      0.618333      6.522333       1.700667
# 126   2025-03-09          Baltimore Orioles            Minnesota Twins           4           3            1            0      0.000000      0.250000      0.634500      6.250000       1.611000      0.628500      5.250000       1.757000
# 127   2025-03-09             Tampa Bay Rays          Toronto Blue Jays           9          13            0            1      0.500000      0.200000      0.747750      5.250000       1.389000      0.830200      5.228000       1.690400
# 128   2025-03-09                  Athletics       Arizona Diamondbacks           5           7            0            1      0.250000      0.000000      0.564000      7.250000       1.583500      0.685000      6.468750       1.312500
# 129   2025-03-10              New York Mets        St. Louis Cardinals           8           0            1            0      0.333333      0.500000      0.537667      3.000000       1.592667      0.683250      4.204250       1.428250
# 130   2025-03-10       Washington Nationals              Miami Marlins           5          10            0            1      0.500000      0.200000      0.695500      2.500000       1.111000      0.589200      7.475000       1.502800
# 131   2025-03-10         Pittsburgh Pirates          Baltimore Orioles           3           6            0            1      0.500000      0.250000      0.748000      7.250000       1.611250      0.587250      8.266750       1.869250
# 132   2025-03-10          Milwaukee Brewers           Seattle Mariners           7           5            1            0      0.333333      0.000000      0.882333      5.333333       1.555667      0.723750      9.000000       1.843750
# 133   2025-03-10           Colorado Rockies       San Francisco Giants           2           8            0            1      0.666667      0.500000      0.770667      4.666667       1.407667      0.817250      4.687500       1.402750
# 134   2025-03-10           San Diego Padres            Cincinnati Reds           3           9            0            1      0.250000      0.250000      0.582250      2.500000       1.139000      0.786750      4.968750       1.645750
# 135   2025-03-10         Los Angeles Angels           Colorado Rockies          12           3            1            0      0.500000      0.500000      0.659000      3.500000       1.111000      0.646500      5.718750       1.336750
# 136   2025-03-10                  Athletics          Chicago White Sox           3          10            0            1      0.200000      0.400000      0.618000      6.800000       1.644600      0.751200      4.925000       1.300000
# 137   2025-03-10        Los Angeles Dodgers       Arizona Diamondbacks           6           2            1            0      0.800000      0.200000      0.879000      4.200000       1.244400      0.676800      6.175000       1.472200
# 138   2025-03-10         Kansas City Royals        Cleveland Guardians           2           5            0            1      0.800000      0.250000      0.969800      4.800000       1.400000      0.866750      6.875000       1.809000
# 139   2025-03-10        Cleveland Guardians               Chicago Cubs           4           7            0            1      0.750000      0.500000      0.768000      3.000000       1.166750      0.941000      6.125000       1.618000
# 140   2025-03-10              Miami Marlins       Washington Nationals           9           9            0            0      0.250000      0.600000      0.750000      5.000000       1.361250      0.795200      3.048000       1.371600
# 141   2025-03-10          Toronto Blue Jays             Houston Astros           8           3            1            0      1.000000      0.500000      0.900667      2.666667       1.000000      0.622500      5.218750       1.625000
# 142   2025-03-10           New York Yankees             Detroit Tigers          10           2            1            0      0.750000      0.333333      0.892000      5.000000       1.277750      0.611667      4.333333       1.287000
# 143   2025-03-10             Atlanta Braves             Tampa Bay Rays           3           4            0            1      0.400000      0.500000      0.660400      1.600000       1.177800      0.783250      3.843750       1.461750
# 144   2025-03-10            Minnesota Twins      Philadelphia Phillies           1           4            0            1      0.500000      0.000000      0.899750      4.750000       1.416500      0.598000      7.312500       1.843750
# 145   2025-03-11       San Francisco Giants                  Athletics           5           3            1            0      1.000000      0.800000      0.927000      3.750000       1.277750      0.735400      3.100000       1.138800
# 146   2025-03-11           San Diego Padres          Chicago White Sox           7           5            1            0      0.200000      0.500000      0.595800      3.800000       1.377800      0.791500      4.604167       1.324000
# 147   2025-03-11       Arizona Diamondbacks         Kansas City Royals           3           2            1            0      0.800000      0.500000      1.046000      4.400000       1.622200      0.687000      5.125000       1.309000
# 148   2025-03-11               Chicago Cubs          Milwaukee Brewers           7           9            0            1      0.500000      0.400000      0.850667      6.166667       1.389000      0.739800      3.950000       1.411000
# 149   2025-03-11              Texas Rangers         Los Angeles Angels          13           6            1            0      0.750000      0.200000      0.892000      3.500000       0.972500      0.757600      8.105000       1.544400
# 150   2025-03-11        Los Angeles Dodgers        Cleveland Guardians          10           4            1            0      0.833333      0.400000      0.869667      3.833333       1.148167      0.864200      5.900000       1.691600
# 151   2025-03-11            Cincinnati Reds           Colorado Rockies           8           5            1            0      0.750000      0.400000      0.775000      4.750000       1.611000      0.633200      7.275000       1.544400
# 152   2025-03-11        St. Louis Cardinals              Miami Marlins           5          12            0            1      0.800000      0.333333      0.819000      3.200000       1.355600      0.641833      7.062500       1.474500
# 153   2025-03-11         Pittsburgh Pirates           New York Yankees           9           1            1            0      0.400000      0.250000      0.735600      6.800000       1.577800      0.813500      5.141750       1.584250
# 154   2025-03-11           New York Yankees          Baltimore Orioles           2           6            0            1      0.800000      0.400000      0.956600      4.200000       1.177800      0.614200      7.213400       1.784200
# 155   2025-03-11             Atlanta Braves             Detroit Tigers           1           3            0            1      0.333333      0.250000      0.624833      2.000000       1.185167      0.560250      6.062500       1.371500
# 156   2025-03-11             Boston Red Sox      Philadelphia Phillies           8          18            0            1      1.000000      0.200000      1.023400      3.000000       1.222200      0.640600      6.050000       1.786200
# 157   2025-03-11             Houston Astros              New York Mets           7           4            1            0      0.500000      0.400000      0.852250      4.000000       1.694500      0.628200      3.775000       1.308400
# 158   2025-03-11          Toronto Blue Jays            Minnesota Twins           3           2            1            0      1.000000      0.200000      0.918000      2.750000       0.972250      0.638000      4.425000       1.680600
# 159   2025-03-12             Boston Red Sox            Minnesota Twins           6           5            1            0      0.833333      0.166667      1.000500      5.500000       1.555500      0.622833      4.250000       1.588000
# 160   2025-03-12           Seattle Mariners         Kansas City Royals           6           7            0            1      0.400000      0.400000      0.867200      5.800000       1.578000      0.703800      4.775000       1.397200
# 161   2025-03-12           Colorado Rockies           San Diego Padres          13           2            1            0      0.500000      0.000000      0.709500      5.500000       1.555750      0.636250      9.562500       2.062500
# 162   2025-03-12          Chicago White Sox         Los Angeles Angels           1           1            0            0      0.333333      0.166667      0.698333      3.000000       1.259333      0.778000      9.004167       1.766167
# 163   2025-03-12              Texas Rangers            Cincinnati Reds           4           3            1            0      0.800000      0.400000      0.961200      4.000000       1.133600      0.808200      4.375000       1.472200
# 164   2025-03-12        Cleveland Guardians       San Francisco Giants           2          11            0            1      0.600000      0.600000      0.754000      3.600000       1.333400      0.838800      4.150000       1.277800
# 165   2025-03-12          Baltimore Orioles             Atlanta Braves           5          13            0            1      0.200000      0.000000      0.623200      5.600000       1.444400      0.682667      6.000000       1.875000
# 166   2025-03-12             Detroit Tigers             Tampa Bay Rays           5           1            1            0      0.800000      0.600000      0.948600      5.800000       1.333000      0.770800      3.675000       1.347200
# 167   2025-03-12        St. Louis Cardinals              New York Mets           0           2            0            1      0.666667      0.333333      0.804333      4.500000       1.444500      0.613667      4.458333       1.444500
# 168   2025-03-12       Washington Nationals             Houston Astros           9           3            1            0      0.400000      0.400000      0.722200      3.200000       1.333200      0.606800      5.975000       1.650000
# 169   2025-03-12                  Athletics       Arizona Diamondbacks           2           5            0            1      0.166667      0.166667      0.614667      7.333333       1.685333      0.638333      6.270833       1.476833
# 170   2025-03-13            Cincinnati Reds                  Athletics           1          12            0            1      0.800000      0.666667      0.822400      4.800000       1.577600      0.719333      3.520833       1.199000
# 171   2025-03-13         Kansas City Royals           San Diego Padres           6           5            1            0      0.666667      0.000000      0.925833      4.833333       1.426000      0.636800     10.575000       2.175000
# 172   2025-03-13           Colorado Rockies        Cleveland Guardians           6           4            1            0      0.600000      0.333333      0.792400      4.800000       1.533400      0.829667      6.791667       1.826333
# 173   2025-03-13       San Francisco Giants              Texas Rangers           3           7            0            1      1.000000      0.200000      0.922000      3.600000       1.266600      0.654000      8.025000       1.850000
# 174   2025-03-13          Chicago White Sox          Milwaukee Brewers           3           9            0            1      0.250000      0.500000      0.710500      2.500000       1.194500      0.798833      4.291667       1.435167
# 175   2025-03-13              Miami Marlins             Houston Astros           5          10            0            1      0.200000      0.333333      0.780200      5.400000       1.444600      0.603500      6.291667       1.770833
# 176   2025-03-13      Philadelphia Phillies             Atlanta Braves          16           9            1            0      0.600000      0.250000      0.821600      3.000000       1.200200      0.813250      5.750000       1.906250
# 177   2025-03-13          Toronto Blue Jays          Baltimore Orioles           6           4            1            0      1.000000      0.500000      0.856800      2.600000       0.977800      0.652000      6.344500       1.635000
# 178   2025-03-13             Detroit Tigers           New York Yankees           6           8            0            1      0.833333      0.200000      0.896167      5.000000       1.240500      0.778000      6.138400       1.642400
# 179   2025-03-13            Minnesota Twins         Pittsburgh Pirates          15           3            1            0      0.400000      0.400000      0.859200      4.600000       1.511000      0.778800      6.080000       1.550800
# 180   2025-03-13             Tampa Bay Rays       Washington Nationals          14           4            1            0      0.400000      0.500000      0.787200      6.000000       1.622400      0.822167      3.540000       1.383667
# 181   2025-03-13             Houston Astros        St. Louis Cardinals           1           1            0            0      0.600000      0.400000      0.871200      4.000000       1.511200      0.625600      5.163400       1.492600
# 182   2025-03-13              New York Mets             Boston Red Sox           2           3            0            1      0.500000      0.250000      0.673250      2.250000       1.444500      0.837750      6.367500       1.647500
# 183   2025-03-14           San Diego Padres              Texas Rangers           9           8            1            0      0.333333      0.333333      0.707667      4.000000       1.351833      0.672333      7.187500       1.689833
# 184   2025-03-14              Texas Rangers           Colorado Rockies           5           0            1            0      0.833333      0.333333      0.923667      3.833333       1.111333      0.668667      7.375000       1.578667
# 185   2025-03-14           New York Yankees      Philadelphia Phillies           6           5            1            0      0.666667      0.333333      0.895167      4.333333       1.222167      0.737833      6.041667       1.821833
# 186   2025-03-14              New York Mets        St. Louis Cardinals           3           3            0            0      0.400000      0.333333      0.627600      2.000000       1.400000      0.600167      4.469500       1.355000
# 187   2025-03-14            Minnesota Twins             Tampa Bay Rays          13           6            1            0      0.500000      0.500000      0.885500      4.000000       1.407333      0.723500      4.000000       1.351833
# 188   2025-03-14          Baltimore Orioles            Minnesota Twins          10           0            1            0      0.166667      0.142857      0.651667      6.166667       1.592500      0.633000      4.533000       1.509429
# 189   2025-03-14         Pittsburgh Pirates             Detroit Tigers           8           8            0            0      0.500000      0.400000      0.792500      5.833333       1.537000      0.573000      5.050000       1.252800
# 190   2025-03-14             Houston Astros          Toronto Blue Jays           6           5            1            0      0.500000      0.333333      0.787500      3.500000       1.389000      0.885333      5.856667       1.723500
# 191   2025-03-14              Miami Marlins             Boston Red Sox           4           9            0            1      0.166667      0.400000      0.777833      5.833333       1.481667      0.796800      5.494000       1.518000
# 192   2025-03-14         Los Angeles Angels         Kansas City Royals           8           9            0            1      0.600000      0.500000      0.774000      3.400000       1.111000      0.752500      4.812500       1.368000
# 193   2025-03-14       Arizona Diamondbacks            Cincinnati Reds           2           1            1            0      0.833333      0.333333      1.000333      4.000000       1.555500      0.768833      4.208333       1.414333
# 194   2025-03-14          Chicago White Sox            Cincinnati Reds           7           3            1            0      0.200000      0.285714      0.735000      4.025000       1.305600      0.717000      3.928571       1.390857
# 195   2025-03-14        Cleveland Guardians           Seattle Mariners           8           7            1            0      0.500000      0.000000      0.713333      4.833333       1.500000      0.734800      8.775000       1.825000
# 196   2025-03-14                  Athletics         Los Angeles Angels          12           1            1            0      0.142857      0.142857      0.601000      6.857143       1.603286      0.716857      7.860714       1.783714
# 197   2025-03-14             Atlanta Braves       Washington Nationals           3           5            0            1      0.285714      0.428571      0.606000      2.142857       1.190429      0.797714      5.284286       1.632429
# 198   2025-03-14          Milwaukee Brewers       San Francisco Giants          11           5            1            0      0.500000      0.666667      0.898750      5.250000       1.527750      0.880500      3.625000       1.213000
# 199   2025-03-15          Chicago White Sox           Colorado Rockies           2           1            1            0      0.333333      0.285714      0.787333      3.854167       1.199167      0.652286      7.125000       1.567429
# 200   2025-03-15           Seattle Mariners           San Diego Padres           3           8            0            1      0.333333      0.000000      0.851667      5.833333       1.574333      0.670000      9.677833       2.024000
# 201   2025-03-15       Arizona Diamondbacks          Chicago White Sox           9           8            1            0      0.857143      0.428571      0.943143      3.571429       1.428571      0.772429      5.071429       1.456286
# 202   2025-03-15       Washington Nationals              New York Mets           4           1            1            0      0.500000      0.428571      0.756833      2.666667       1.314667      0.596571      3.821429       1.301571
# ...
# 1801  2025-07-13         Kansas City Royals              New York Mets           3           2            1            0      0.500000      0.466667      0.692733      3.747583       1.217050      0.689750      4.053367       1.367250
# 1802  2025-07-13             Detroit Tigers           Seattle Mariners           4           8            0            1      0.633333      0.442623      0.757883      3.638783       1.177917      0.773410      5.098410       1.447689
# 1803  2025-07-13            Cincinnati Reds           Colorado Rockies           4           2            1            0      0.539683      0.258065      0.720619      4.315159       1.295032      0.604952      5.232097       1.480984
# 1804  2025-07-13           New York Yankees               Chicago Cubs           1           4            0            1      0.583333      0.537037      0.778267      3.624900       1.189100      0.755667      4.226537       1.299981
# 1805  2025-07-13          Baltimore Orioles              Miami Marlins           1          11            0            1      0.438596      0.474576      0.734684      5.215789       1.415596      0.707424      5.441051       1.444831
# 1806  2025-07-13             Boston Red Sox             Tampa Bay Rays           4           1            1            0      0.630769      0.490909      0.790400      3.949923       1.371785      0.688491      4.149273       1.286527
# 1807  2025-07-13             Houston Astros              Texas Rangers           1           5            0            1      0.609375      0.387097      0.740078      3.666187       1.210641      0.665677      4.391613       1.300081
# 1808  2025-07-15  National League All-Stars  American League All-Stars           7           6            1            0      0.000000      0.000000      0.000000      0.000000       0.000000      0.000000      0.000000       0.000000
# 1809  2025-07-18        Los Angeles Dodgers          Milwaukee Brewers           0           2            0            1      0.689655      0.491525      0.824103      4.418966       1.291345      0.737322      4.696661       1.425695
# 1810  2025-07-18           Seattle Mariners             Houston Astros           6           1            1            0      0.526316      0.545455      0.707754      3.660614       1.195298      0.712036      3.916655       1.269255
# 1811  2025-07-18       Arizona Diamondbacks        St. Louis Cardinals           7           3            1            0      0.516129      0.450000      0.789694      4.483581       1.352887      0.677850      4.476233       1.349817
# 1812  2025-07-18           Colorado Rockies            Minnesota Twins           6           4            1            0      0.298246      0.366667      0.726035      5.906544       1.631544      0.647433      4.299033       1.316283
# 1813  2025-07-18              Texas Rangers             Detroit Tigers           2           0            1            0      0.586207      0.516667      0.682241      3.006345       1.132707      0.704417      4.282183       1.304950
# 1814  2025-07-18             Tampa Bay Rays          Baltimore Orioles          11           1            1            0      0.515625      0.450000      0.754531      3.896875       1.235406      0.652817      5.071700       1.450300
# 1815  2025-07-18             Atlanta Braves           New York Yankees           7           3            1            0      0.465517      0.475410      0.691310      3.240914       1.200621      0.786623      4.663328       1.356115
# 1816  2025-07-18        Cleveland Guardians                  Athletics           8           6            1            0      0.490566      0.466667      0.657792      4.067925       1.352623      0.700600      5.178033       1.432250
# 1817  2025-07-18              New York Mets            Cincinnati Reds           4           8            0            1      0.627119      0.423729      0.731373      3.043288       1.227966      0.665610      4.130831       1.324085
# 1818  2025-07-18          Toronto Blue Jays       San Francisco Giants           4           0            1            0      0.728814      0.508475      0.794203      3.899627       1.220525      0.689271      3.729271       1.248424
# 1819  2025-07-18      Philadelphia Phillies         Los Angeles Angels           5           6            0            1      0.655172      0.403226      0.785828      3.950621       1.240172      0.683129      5.145468       1.533226
# 1820  2025-07-18       Washington Nationals           San Diego Padres           2           7            0            1      0.379310      0.406780      0.672862      5.110966       1.440224      0.673898      5.014305       1.433322
# 1821  2025-07-18         Pittsburgh Pirates          Chicago White Sox           1          10            0            1      0.551724      0.271186      0.699241      3.639810       1.209241      0.656864      4.696576       1.487492
# 1822  2025-07-18               Chicago Cubs             Boston Red Sox           4           1            1            0      0.586207      0.465517      0.736379      4.325379       1.265638      0.707621      4.281569       1.325362
# 1823  2025-07-18              Miami Marlins         Kansas City Royals           8           7            1            0      0.389831      0.524590      0.679068      4.548695       1.315068      0.708098      3.987705       1.309738
# 1824  2025-07-19        Cleveland Guardians                  Athletics           2           8            0            1      0.500000      0.459016      0.664444      4.103704       1.346093      0.703230      5.222246       1.435410
# 1825  2025-07-19        Los Angeles Dodgers          Milwaukee Brewers           7           8            0            1      0.677966      0.500000      0.814898      4.377966       1.290169      0.735883      4.618383       1.409333
# 1826  2025-07-19           Colorado Rockies            Minnesota Twins          10           6            1            0      0.310345      0.360656      0.733034      5.873672       1.628310      0.650033      4.339213       1.327492
# 1827  2025-07-19             Atlanta Braves           New York Yankees           9          12            0            1      0.474576      0.467742      0.694712      3.236831       1.202864      0.784548      4.715129       1.360452
# 1828  2025-07-19           Seattle Mariners             Houston Astros           7           6            1            0      0.534483      0.535714      0.708776      3.614741       1.188103      0.705875      3.967250       1.268911
# 1829  2025-07-19               Chicago Cubs             Boston Red Sox           6           0            1            0      0.593220      0.457627      0.735102      4.269017       1.264898      0.705051      4.285271       1.324085
# 1830  2025-07-19              Texas Rangers             Detroit Tigers           4           1            1            0      0.593220      0.508197      0.678576      2.955390       1.128576      0.699311      4.248869       1.295852
# 1831  2025-07-19       Arizona Diamondbacks        St. Louis Cardinals          10           1            1            0      0.523810      0.442623      0.790175      4.460032       1.350810      0.678607      4.513508       1.356377
# 1832  2025-07-19       Washington Nationals           San Diego Padres           4           2            1            0      0.372881      0.416667      0.673305      5.142983       1.444068      0.677350      4.964067       1.427950
# 1833  2025-07-19         Pittsburgh Pirates          Chicago White Sox           4          10            0            1      0.542373      0.283333      0.694593      3.747610       1.222644      0.662617      4.634967       1.475667
# 1834  2025-07-19      Philadelphia Phillies         Los Angeles Angels           9           5            1            0      0.644068      0.412698      0.786458      3.985356       1.245525      0.687984      5.143159       1.526524
# 1835  2025-07-19              Miami Marlins         Kansas City Royals           3           1            1            0      0.400000      0.516129      0.682817      4.562883       1.316483      0.709919      4.032258       1.311081
# 1836  2025-07-19              New York Mets            Cincinnati Reds           2           5            0            1      0.616667      0.433333      0.728483      3.125900       1.235283      0.671667      4.095317       1.318683
# 1837  2025-07-19          Toronto Blue Jays       San Francisco Giants           6           3            1            0      0.733333      0.500000      0.794083      3.834633       1.220550      0.688433      3.742117       1.254700
# 1838  2025-07-19             Tampa Bay Rays          Baltimore Orioles           4           3            1            0      0.523077      0.442623      0.760738      3.852308       1.228369      0.649590      5.191426       1.463410
# 1839  2025-07-20              Texas Rangers             Detroit Tigers           1           2            0            1      0.600000      0.500000      0.675600      2.922800       1.122733      0.694581      4.252919       1.291081
# 1840  2025-07-20        Los Angeles Dodgers          Milwaukee Brewers           5           6            0            1      0.666667      0.508197      0.815750      4.438333       1.300150      0.740803      4.657426       1.409902
# 1841  2025-07-20       Arizona Diamondbacks        St. Louis Cardinals           5           3            1            0      0.531250      0.435484      0.795281      4.405969       1.343594      0.677516      4.585871       1.362726
# 1842  2025-07-20           Colorado Rockies            Minnesota Twins           1           7            0            1      0.322034      0.354839      0.739153      5.875814       1.623305      0.651903      4.450677       1.338339
# 1843  2025-07-20               Chicago Cubs             Boston Red Sox           1           6            0            1      0.600000      0.450000      0.741617      4.197867       1.256783      0.700267      4.326350       1.327017
# 1844  2025-07-20              Miami Marlins         Kansas City Royals           4           7            0            1      0.409836      0.507937      0.683852      4.504475       1.305836      0.705127      4.021825       1.312095
# 1845  2025-07-20        Cleveland Guardians                  Athletics           8           2            1            0      0.490909      0.467742      0.660236      4.174545       1.351927      0.710339      5.170274       1.424806
# 1846  2025-07-20           Seattle Mariners             Houston Astros           3          11            0            1      0.542373      0.526316      0.707034      3.622814       1.195695      0.705947      3.974053       1.268719
# 1847  2025-07-20             Atlanta Braves           New York Yankees           2           4            0            1      0.466667      0.476190      0.698500      3.366217       1.212450      0.788873      4.783143       1.370603
# 1848  2025-07-20         Pittsburgh Pirates          Chicago White Sox           2           7            0            1      0.533333      0.295082      0.697417      3.851817       1.233750      0.666443      4.608164       1.480623
# 1849  2025-07-20      Philadelphia Phillies         Los Angeles Angels           2           8            0            1      0.650000      0.406250      0.790300      4.002267       1.248833      0.692297      5.221000       1.533922
# 1850  2025-07-20       Washington Nationals           San Diego Padres           1           8            0            1      0.383333      0.409836      0.673467      5.090600       1.434817      0.674197      4.956459       1.422984
# 1851  2025-07-20             Tampa Bay Rays          Baltimore Orioles           3           5            0            1      0.530303      0.435484      0.757045      3.839394       1.228273      0.650758      5.162129       1.459968
# 1852  2025-07-20          Toronto Blue Jays       San Francisco Giants           8           6            1            0      0.737705      0.491803      0.797525      3.820951       1.207820      0.685623      3.791426       1.264869
# 1853  2025-07-20              New York Mets            Cincinnati Reds           3           2            1            0      0.606557      0.442623      0.726689      3.140230       1.233246      0.670344      4.060967       1.320738
# 1854  2025-07-21       Arizona Diamondbacks             Houston Astros           3           6            0            1      0.538462      0.534483      0.794692      4.384338       1.341723      0.710103      3.957259       1.269828
# 1855  2025-07-21           Colorado Rockies        St. Louis Cardinals           2           6            0            1      0.316667      0.428571      0.735967      5.894550       1.627733      0.676079      4.602365       1.358952
# 1856  2025-07-21              Texas Rangers                  Athletics           7           2            1            0      0.590164      0.460317      0.669820      2.907672       1.128000      0.707825      5.231063       1.427984
# 1857  2025-07-21               Chicago Cubs         Kansas City Royals           4          12            0            1      0.590164      0.515625      0.739115      4.227410       1.258033      0.707266      3.958984       1.310688
# 1858  2025-07-21             Tampa Bay Rays          Chicago White Sox           3           8            0            1      0.522388      0.306452      0.754910      3.856716       1.226522      0.669661      4.549968       1.467500
# 1859  2025-07-21             Atlanta Braves       San Francisco Giants           9           5            1            0      0.459016      0.483871      0.696984      3.376607       1.214426      0.688565      3.875435       1.272694
# 1860  2025-07-21       Washington Nationals            Cincinnati Reds          10           8            1            0      0.377049      0.435484      0.670885      5.138295       1.444082      0.668290      4.049903       1.319597
# 1861  2025-07-21          Toronto Blue Jays           New York Yankees           4           1            1            0      0.741935      0.484375      0.801855      3.856097       1.213435      0.787266      4.739656       1.361344
# 1862  2025-07-21      Philadelphia Phillies             Boston Red Sox           3           2            1            0      0.639344      0.459016      0.785820      4.051410       1.262967      0.702410      4.271820       1.323475
# 1863  2025-07-21              Miami Marlins           San Diego Padres           1           2            0            1      0.403226      0.419355      0.680839      4.512468       1.306274      0.679435      4.892645       1.414371
# 1864  2025-07-21         Pittsburgh Pirates             Detroit Tigers           3           0            1            0      0.524590      0.507937      0.692541      3.903426       1.235377      0.693651      4.201286       1.277635
# 1865  2025-07-21        Cleveland Guardians          Baltimore Orioles          10           5            1            0      0.500000      0.444444      0.665375      4.135714       1.343661      0.653540      5.127810       1.457952
# 1866  2025-07-21           Seattle Mariners          Milwaukee Brewers           0           6            0            1      0.533333      0.516129      0.706633      3.729100       1.203550      0.739710      4.646823       1.401500
# 1867  2025-07-21              New York Mets         Los Angeles Angels           7           5            1            0      0.612903      0.415385      0.724694      3.105710       1.231274      0.695123      5.171446       1.524000
# 1868  2025-07-21        Los Angeles Dodgers            Minnesota Twins           5           2            1            0      0.655738      0.365079      0.812934      4.431148       1.304344      0.661222      4.395905       1.327683
